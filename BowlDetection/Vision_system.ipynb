# %% [markdown]
# Toilet bowl detection node

# %% [markdown]
# for run this node this 3 files (node_code.py - if alailable) should be in same directory
#
# object_detection_nanodet_2022nov.onnx
# object_detection_nanodet_2022nov_int8.onnx
# nanodet.py

# %%
# import libs and ros2 msgs
import rclpy
from rclpy.node import Node
from sensor_msgs.msg import Image
from cv_bridge import CvBridge
import cv2 as cv
import numpy as np
import pyrealsense2 as rs
import threading
import argparse
from std_msgs.msg import Int32MultiArray
from std_msgs.msg import String
import json
from nanodet import NanoDet

# %%
# Check OpenCV version
assert cv.__version__ >= "4.9.0", \
       "Please install latest opencv-python to try this demo: python3 -m pip install --upgrade opencv-python"

# Valid combinations of backends and targets
backend_target_pairs = [
    [cv.dnn.DNN_BACKEND_OPENCV, cv.dnn.DNN_TARGET_CPU],
    [cv.dnn.DNN_BACKEND_CUDA,   cv.dnn.DNN_TARGET_CUDA],
    [cv.dnn.DNN_BACKEND_CUDA,   cv.dnn.DNN_TARGET_CUDA_FP16],
    [cv.dnn.DNN_BACKEND_TIMVX,  cv.dnn.DNN_TARGET_NPU],
    [cv.dnn.DNN_BACKEND_CANN,   cv.dnn.DNN_TARGET_NPU]
]

# %%
# all classes for machine learning model
classes = ('person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
           'train', 'truck', 'boat', 'traffic light', 'fire hydrant',
           'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog',
           'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe',
           'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee',
           'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat',
           'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
           'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
           'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot',
           'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch',
           'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop',
           'mouse', 'remote', 'keyboard', 'cell phone', 'microwave',
           'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock',
           'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush')

# %%
def letterbox(srcimg, target_size=(416, 416)):
    img = srcimg.copy()

    top, left, newh, neww = 0, 0, target_size[0], target_size[1]
    if img.shape[0] != img.shape[1]:
        hw_scale = img.shape[0] / img.shape[1]
        if hw_scale > 1:
            newh, neww = target_size[0], int(target_size[1] / hw_scale)
            img = cv.resize(img, (neww, newh), interpolation=cv.INTER_AREA)
            left = int((target_size[1] - neww) * 0.5)
            img = cv.copyMakeBorder(img, 0, 0, left, target_size[1] - neww - left, cv.BORDER_CONSTANT, value=0)  # add border
        else:
            newh, neww = int(target_size[0] * hw_scale), target_size[1]
            img = cv.resize(img, (neww, newh), interpolation=cv.INTER_AREA)
            top = int((target_size[0] - newh) * 0.5)
            img = cv.copyMakeBorder(img, top, target_size[0] - newh - top, 0, 0, cv.BORDER_CONSTANT, value=0)
    else:
        img = cv.resize(img, target_size, interpolation=cv.INTER_AREA)

    letterbox_scale = [top, left, newh, neww]
    return img, letterbox_scale

# %%
def unletterbox(bbox, original_image_shape, letterbox_scale):
    ret = bbox.copy()

    h, w = original_image_shape
    top, left, newh, neww = letterbox_scale

    if h == w:
        ratio = h / newh
        ret = ret * ratio
        return ret

    ratioh, ratiow = h / newh, w / neww
    ret[0] = max((ret[0] - left) * ratiow, 0)
    ret[1] = max((ret[1] - top) * ratioh, 0)
    ret[2] = min((ret[2] - left) * ratiow, w)
    ret[3] = min((ret[3] - top) * ratioh, h)

    return ret.astype(np.int32)

# %%
def vis(preds, res_img, letterbox_scale, fps=None):
    ret = res_img.copy()
    A_x_values = []
    A_y_values = []
    B_x_values = []
    B_y_values = []
    angle = []

    # draw FPS
    if fps is not None:
        fps_label = "FPS: %.2f" % fps
        cv.putText(ret, fps_label, (10, 25), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # draw bboxes and labels for toilet class only
    for pred in preds:
        bbox = pred[:4]
        conf = pred[-2]
        classid = pred[-1].astype(np.int32)

        if classes[classid] == 'toilet':
            # bbox
            xmin, ymin, xmax, ymax = unletterbox(bbox, ret.shape[:2], letterbox_scale)
            cv.rectangle(ret, (xmin, ymin), (xmax, ymax), (0, 255, 0), thickness=2)

            # label
            label = "{:s}: {:.2f}".format(classes[classid], conf)
            cv.putText(ret, label, (xmin, ymax + 20), cv.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), thickness=2)
            
            # Define ROI within the bounding box (adjust the percentages as needed)
            roi_xmin = int(xmin + 0.05 * (xmax - xmin))  # 10% offset from xmin left
            roi_ymin = int(ymin + 0.35 * (ymax - ymin))  # 10% offset from ymin  up
            roi_xmax = int(xmax - 0.05 * (xmax - xmin))  # 10% offset from xmax  right
            roi_ymax = int(ymax - 0.01 * (ymax - ymin))  # 10% offset from ymax  down

            # Draw a red rectangle around the ROI
            cv.rectangle(ret, (roi_xmin, roi_ymin), (roi_xmax, roi_ymax), (225, 0, 255), thickness=1)
   
            canny_low = 4
            canny_high = 150
           
            # Fit an ellipse only within the ROI
            roi_gray = cv.cvtColor(ret[roi_ymin:roi_ymax, roi_xmin:roi_xmax], cv.COLOR_BGR2GRAY)
            blurred = cv.GaussianBlur(roi_gray, (3, 3), 0)
            edges = cv.Canny(blurred, canny_low, canny_high)
            contours, _ = cv.findContours(edges, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

            # Concatenate arrays vertically
            numpy_vertical = np.vstack((blurred, edges))  # Use the same array twice for demonstration
            #cv.imshow('Numpy Vertical', numpy_vertical)


            min_points= 5

            # Filter out contours that represent complete ellipses
            for contour in contours:
                if len(contour) >= min_points:  # Minimum number of points required to fit an ellipse originl 5
                    # Fit an ellipse to the contour
                    ellipse = cv.fitEllipse(contour)

                    # Ensure that the ellipse's width and height are not zero to avoid ZeroDivisionError
                    if ellipse[1][0] != 0 and ellipse[1][1] != 0:
                        # Calculate contour area and ellipse area
                        contour_area = cv.contourArea(contour)
                        ellipse_area = np.pi * ellipse[1][0] * ellipse[1][1] / 4

                        ratio = contour_area / ellipse_area
                        if 25000 > contour_area >= 12000:
                            if ratio > 0.2:  # Adjust this threshold as needed original 0.9
                                # Offset ellipse coordinates by the bounding box coordinates
                                ellipse = ((ellipse[0][0] + roi_xmin, ellipse[0][1] + roi_ymin ), ellipse[1], ellipse[2])
                                cv.ellipse(ret, ellipse, (0, 255, 0), 2)
                                
                                # Mark the center of the ellipse
                                cv.circle(ret, (int(ellipse[0][0]), int(ellipse[0][1])), 5, (55, 25, 255), -1)
                                cv.putText(ret, "{:.2f} Sq.cm".format(contour_area), (int(ellipse[0][0])+ 10, int(ellipse[0][1]) - 10),cv.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

                                # Draw the perpendicular axis to the ellipse's plane
                                angle_rad = np.deg2rad(ellipse[2])
                                axis_length = max(ellipse[1][0], ellipse[1][1])

                                cv.line(ret, (int(ellipse[0][0]), int(ellipse[0][1])-100), (int(ellipse[0][0]), int(ellipse[0][1])+100), (0, 0, 220), 2)  # fix horizontal red

                                # Calculate the distance between the endpoints of the line
                                line_length = np.sqrt((ellipse[0][0] - int(ellipse[0][0] - axis_length * np.sin(angle_rad))) ** 2 +
                                                    (ellipse[0][1] - int(ellipse[0][1] + axis_length * np.cos(angle_rad))) ** 2)
                                
                                # Draw the line 
                                cv.line(ret, (int(ellipse[0][0] - axis_length * np.sin(angle_rad)), int(ellipse[0][1] + axis_length * np.cos(angle_rad))),   # diameter blue
                                        (int(ellipse[0][0] + axis_length * np.sin(angle_rad)), int(ellipse[0][1] - axis_length * np.cos(angle_rad))),
                                        (255, 155, 0), 2)
                                
                                # Define the desired length of the line
                                line_length = 120  # Adjust as needed for your desired length

                                grid_color = (255, 255, 255)

                                # Calculate the change in x and y for the desired length
                                delta_x_length = line_length * np.sin(angle_rad)
                                delta_y_length = line_length * np.cos(angle_rad)

                                line_start = (int(ellipse[0][0] - delta_x_length)-50, int(ellipse[0][1] + delta_y_length))
                                line_end = (int(ellipse[0][0] + delta_x_length)-50, int(ellipse[0][1] - delta_y_length))
                                cv.line(ret, line_start, line_end, grid_color, 2)
                                
                                line_start = (int(ellipse[0][0] - delta_x_length)-100, int(ellipse[0][1] + delta_y_length))
                                line_end = (int(ellipse[0][0] + delta_x_length)-100, int(ellipse[0][1] - delta_y_length))
                                cv.line(ret, line_start, line_end, grid_color, 2)


                                line_start = (int(ellipse[0][0] - delta_x_length)+50, int(ellipse[0][1] + delta_y_length))
                                line_end = (int(ellipse[0][0] + delta_x_length)+50, int(ellipse[0][1] - delta_y_length))
                                cv.line(ret, line_start, line_end, grid_color, 2)
                                
                                line_start = (int(ellipse[0][0] - delta_x_length)+100, int(ellipse[0][1] + delta_y_length))
                                line_end = (int(ellipse[0][0] + delta_x_length)+100, int(ellipse[0][1] - delta_y_length))
                                cv.line(ret, line_start, line_end, grid_color, 2)


                                # Define the desired length of the perpendicular lines
                                perpendicular_length = 120  # Adjust as needed for your desired length

                                # Calculate the slope of the original line
                                original_slope = np.tan(angle_rad)

                                # Calculate the slope of the perpendicular line
                                perpendicular_slope = -1 / original_slope

                                # Calculate the change in x and y for the desired length for perpendicular lines
                                delta_x_perpendicular = perpendicular_length * np.cos(angle_rad)
                                delta_y_perpendicular = perpendicular_length * np.sin(angle_rad)

                                # Calculate the start and end points for the first perpendicular line
                                line_start_perpendicular_1 = (int(ellipse[0][0] - delta_x_perpendicular), int(ellipse[0][1] - delta_y_perpendicular))
                                line_end_perpendicular_1 = (int(ellipse[0][0] + delta_x_perpendicular), int(ellipse[0][1] + delta_y_perpendicular))
                                cv.line(ret, line_start_perpendicular_1, line_end_perpendicular_1, grid_color, 2)
                                
                                line_start_perpendicular_1 = (int(ellipse[0][0] - delta_x_perpendicular), int(ellipse[0][1] - delta_y_perpendicular)+100)
                                line_end_perpendicular_1 = (int(ellipse[0][0] + delta_x_perpendicular), int(ellipse[0][1] + delta_y_perpendicular)+100)
                                cv.line(ret, line_start_perpendicular_1, line_end_perpendicular_1, grid_color, 2)

                                line_start_perpendicular_1 = (int(ellipse[0][0] - delta_x_perpendicular), int(ellipse[0][1] - delta_y_perpendicular)+50)
                                line_end_perpendicular_1 = (int(ellipse[0][0] + delta_x_perpendicular), int(ellipse[0][1] + delta_y_perpendicular)+50)
                                cv.line(ret, line_start_perpendicular_1, line_end_perpendicular_1, grid_color, 2)

                                line_start_perpendicular_1 = (int(ellipse[0][0] - delta_x_perpendicular), int(ellipse[0][1] - delta_y_perpendicular)-100)
                                line_end_perpendicular_1 = (int(ellipse[0][0] + delta_x_perpendicular), int(ellipse[0][1] + delta_y_perpendicular)-100)
                                cv.line(ret, line_start_perpendicular_1, line_end_perpendicular_1, grid_color, 2)

                                line_start_perpendicular_1 = (int(ellipse[0][0] - delta_x_perpendicular), int(ellipse[0][1] - delta_y_perpendicular)-50)
                                line_end_perpendicular_1 = (int(ellipse[0][0] + delta_x_perpendicular), int(ellipse[0][1] + delta_y_perpendicular)-50)
                                cv.line(ret, line_start_perpendicular_1, line_end_perpendicular_1, grid_color, 2)

                                # Calculate the fraction of the distance along the line where you want to place the dot 
                                dot_fraction = 0.60

                                # Calculate the coordinates of the dot along the line
                                dot_x = int(ellipse[0][0] - (axis_length * np.sin(angle_rad)) * dot_fraction)
                                dot_y = int(ellipse[0][1] + (axis_length * np.cos(angle_rad)) * dot_fraction)

                                # Draw the dot on the line
                                cv.circle(ret, (dot_x, dot_y), radius=5, color=(0, 255, 255), thickness=-1)  # thickness=-1 fills the circle
                                
                                #print("A[x,y]", " ", abs(dot_x),",", abs(dot_y))
                                
                                if 480 < dot_y:
                                    print("Bad dot_y val ", dot_y)
                                    dot_y = 300

                                if 640 > dot_x and 480 > dot_y:
                                    #depth_value = depth_frame.get_distance(abs(dot_x), abs(dot_y))
                                    depth_value = 0
                                    depth_value_cm = abs(depth_value) * 100
                                

                                if depth_value_cm != 0:
                                    cv.putText(ret, "A {:.2f} cm".format(depth_value_cm), (dot_x + 10, dot_y - 10),
                                            cv.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)
                                
                                #print("Depth to A"," ", depth_value_cm)
                                
                                bdot_fraction = -0.60

                                # Calculate the coordinates of the dot along the line
                                bdot_x = int(ellipse[0][0] - (axis_length * np.sin(angle_rad)) * bdot_fraction)
                                bdot_y = int(ellipse[0][1] + (axis_length * np.cos(angle_rad)) * bdot_fraction)

                                # Draw the dot on the line
                                cv.circle(ret, (bdot_x, bdot_y), radius=5, color=(0, 255, 255), thickness=-1)  # thickness=-1 fills the circle
                                
                                #print("B dot_x", bdot_x," ", abs(bdot_x), "B dot_y", bdot_y," ", abs(bdot_y))
                                
                                if 480 < bdot_y:
                                    print("Bad bdot_y val ", bdot_y)
                                    bdot_y = 300    
                                
                                # Define the endpoints of the two lines
                                line1_start = (int(ellipse[0][0] - axis_length * np.sin(angle_rad)), int(ellipse[0][1] + axis_length * np.cos(angle_rad)))
                                line1_end = (int(ellipse[0][0] + axis_length * np.sin(angle_rad)), int(ellipse[0][1] - axis_length * np.cos(angle_rad)))
                                line2_start = (int(ellipse[0][0]), int(ellipse[0][1])-100)
                                line2_end = (int(ellipse[0][0]), int(ellipse[0][1])+100)

                                # Calculate the vectors representing the lines
                                vector1 = np.array([line1_end[0] - line1_start[0], line1_end[1] - line1_start[1]])
                                vector2 = np.array([line2_end[0] - line2_start[0], line2_end[1] - line2_start[1]])

                                # Calculate the dot product of the vectors
                                dot_product = np.dot(vector1, vector2)

                                # Calculate the magnitudes of the vectors
                                magnitude1 = np.linalg.norm(vector1)
                                magnitude2 = np.linalg.norm(vector2)

                                # Calculate the cosine of the angle between the lines using the dot product formula
                                cosine_angle = dot_product / (magnitude1 * magnitude2)

                                # Calculate the angle in radians
                                angle_radians = np.arccos(cosine_angle)

                                # Convert the angle from radians to degrees
                                angle_degrees = np.degrees(angle_radians)
                                
                                if angle_degrees > 90:
                                    angle_degrees = angle_degrees - 180
                                    #print("Angle: ", "{:.2f} deg".format(angle_degrees))
                                else:
                                    angle_degrees = angle_degrees
                                    #print("Angle: ", "{:.2f} deg".format(angle_degrees))
                                
                                cv.putText(ret, "{:.2f} deg".format(angle_degrees), (int(ellipse[0][0])+ 10, int(ellipse[0][1]) + 15),cv.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
                                
                                A_x_values.append(abs(dot_x))
                                A_y_values.append(abs(dot_y))
                                B_x_values.append(abs(bdot_x))
                                B_y_values.append(abs(bdot_y))
                                #angle_degrees = round(angle_degrees, 2)
                                angle_degrees = round(angle_degrees)
                                angle.append(angle_degrees)
            
            
    return ret, A_x_values, A_y_values, B_x_values, B_y_values, angle

# %%
class JSONPublisher(Node):
    def __init__(self):
        super().__init__('json_publisher')
        self.publisher_json = self.create_publisher(String, 'json_data', 10)
        self.publisher_image = self.create_publisher(Image, 'annotated_image', 10)
        timer_period = 0.2  # seconds
        self.timer = self.create_timer(timer_period, self.timer_callback)
        
        self.pipeline = rs.pipeline()
        config = rs.config()
        config.enable_stream(rs.stream.depth, 640, 480, rs.format.z16, 30)
        config.enable_stream(rs.stream.color, 640, 480, rs.format.bgr8, 30)
        self.pipeline.start(config)
        self.bridge = CvBridge()
        
        self.model = NanoDet(
            modelPath='object_detection_nanodet_2022nov.onnx',
            prob_threshold=0.35,
            iou_threshold=0.6,
            backend_id=cv.dnn.DNN_BACKEND_OPENCV,
            target_id=cv.dnn.DNN_TARGET_CPU
        )
 
    def timer_callback(self):
        frames = self.pipeline.wait_for_frames()
        depth_frame = frames.get_depth_frame()
        color_frame = frames.get_color_frame()
        if not depth_frame or not color_frame:
            return

        depth_image = np.asanyarray(depth_frame.get_data())
        color_image = np.asanyarray(color_frame.get_data())
        input_blob, letterbox_scale = letterbox(color_image)
        preds = self.model.infer(input_blob)
        annotated_image, A_x_values, A_y_values, B_x_values, B_y_values, angle = vis(preds, color_image, letterbox_scale)
        
        # Check if all required values are not None and not empty lists
        if A_x_values is not None and A_y_values is not None and B_x_values is not None and B_y_values is not None and angle is not None \
                and A_x_values and A_y_values and B_x_values and B_y_values and angle:
            # All parameters are available and not empty, proceed with publishing
            data = {
                "yaw": angle,
                "point_A": {
                    "x": A_x_values,
                    "y": A_y_values
                },
                "point_B": {
                    "x": B_x_values,
                    "y": B_y_values
                }
            }
            json_str = json.dumps(data)  # Convert dictionary to JSON formatted string
            msg_json = String()
            msg_json.data = json_str
            self.publisher_json.publish(msg_json)
            self.get_logger().info('Publishing JSON data: "%s"' % msg_json.data)
        else:
            # Skip publishing if any of the parameters are None or empty
            self.get_logger().info('Skipping JSON data publishing due to missing or empty parameters')

        # add U shape to screen
        center = (annotated_image.shape[1] // 2, (annotated_image.shape[0] // 2)+50)  # Center of the frame
        radius = 90  # Radius of the semicircle
        color = (0, 0, 255)  # Color of the semicircle (green)
        thickness = 2  # Thickness of the semicircle
        cv.ellipse(annotated_image, center, (radius, radius), 0, 0, 180, color, thickness)
        
        # Convert the annotated image to a ROS Image message
        msg_image = self.bridge.cv2_to_imgmsg(annotated_image, encoding='bgr8')
        self.publisher_image.publish(msg_image)
        self.get_logger().info('Publishing annotated image')

# %%
def main(args=None):
    rclpy.init(args=args)
    json_publisher = JSONPublisher()
    rclpy.spin(json_publisher)
    json_publisher.destroy_node()
    rclpy.shutdown()
 
if __name__ == '__main__':
    main()
# Out:
# [INFO] [1714463950.804445189] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463950.815204505] [json_publisher]: Publishing annotated image
# [INFO] [1714463950.927016435] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463950.937092874] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.059934312] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463951.067159282] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.203987958] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463951.211059212] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.391642163] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463951.398546337] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.562008065] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463951.569598646] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.789849374] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463951.796451927] [json_publisher]: Publishing annotated image
# [INFO] [1714463951.963609314] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463951.970677139] [json_publisher]: Publishing annotated image
# [INFO] [1714463952.168987999] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463952.178067121] [json_publisher]: Publishing annotated image
# [INFO] [1714463952.365835646] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463952.372669118] [json_publisher]: Publishing annotated image
# [INFO] [1714463952.566958818] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463952.574602508] [json_publisher]: Publishing annotated image
# [INFO] [1714463952.762031865] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463952.769204352] [json_publisher]: Publishing annotated image
# [INFO] [1714463952.961791989] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463952.968449478] [json_publisher]: Publishing annotated image
# [INFO] [1714463953.163695168] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463953.172137332] [json_publisher]: Publishing annotated image
# [INFO] [1714463953.365627462] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463953.375982785] [json_publisher]: Publishing annotated image
# [INFO] [1714463953.565754408] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463953.572989535] [json_publisher]: Publishing annotated image
# [INFO] [1714463953.761009972] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463953.767448075] [json_publisher]: Publishing annotated image
# [INFO] [1714463953.978258905] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463953.985006509] [json_publisher]: Publishing annotated image
# [INFO] [1714463954.156224628] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [285]}}"
# [INFO] [1714463954.162253433] [json_publisher]: Publishing annotated image
# [INFO] [1714463954.407779229] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463954.414484542] [json_publisher]: Publishing annotated image
# [INFO] [1714463954.566596519] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463954.573215353] [json_publisher]: Publishing annotated image
# [INFO] [1714463954.807005147] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463954.814297131] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.004695188] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463955.014582475] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.191600220] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463955.197997281] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.415713574] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463955.422535028] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.599755478] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463955.615751556] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.800546890] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463955.809259947] [json_publisher]: Publishing annotated image
# [INFO] [1714463955.989962374] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463955.996324434] [json_publisher]: Publishing annotated image
# [INFO] [1714463956.183458844] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463956.191184097] [json_publisher]: Publishing annotated image
# [INFO] [1714463956.407591077] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463956.423808349] [json_publisher]: Publishing annotated image
# [INFO] [1714463956.566140565] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463956.573698912] [json_publisher]: Publishing annotated image
# [INFO] [1714463956.765466323] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463956.773523901] [json_publisher]: Publishing annotated image
# [INFO] [1714463956.974767858] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463956.986082232] [json_publisher]: Publishing annotated image
# [INFO] [1714463957.168192844] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463957.180952138] [json_publisher]: Publishing annotated image
# [INFO] [1714463957.395166701] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463957.405665566] [json_publisher]: Publishing annotated image
# [INFO] [1714463957.612624674] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463957.624269728] [json_publisher]: Publishing annotated image
# [INFO] [1714463957.805834222] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463957.818523984] [json_publisher]: Publishing annotated image
# [INFO] [1714463957.982550348] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463957.992938570] [json_publisher]: Publishing annotated image
# [INFO] [1714463958.174956282] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463958.181830852] [json_publisher]: Publishing annotated image
# [INFO] [1714463958.359457342] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463958.366244080] [json_publisher]: Publishing annotated image
# [INFO] [1714463958.554507597] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463958.560874348] [json_publisher]: Publishing annotated image
# [INFO] [1714463958.812911324] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463958.822365093] [json_publisher]: Publishing annotated image
# [INFO] [1714463958.965272934] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463958.972080906] [json_publisher]: Publishing annotated image
# [INFO] [1714463959.183413969] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463959.192648723] [json_publisher]: Publishing annotated image
# [INFO] [1714463959.379495844] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463959.386832346] [json_publisher]: Publishing annotated image
# [INFO] [1714463959.547149649] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463959.553670046] [json_publisher]: Publishing annotated image
# [INFO] [1714463959.766058529] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463959.772649528] [json_publisher]: Publishing annotated image
# [INFO] [1714463959.984718874] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463959.991438441] [json_publisher]: Publishing annotated image
# [INFO] [1714463960.187062985] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463960.197076857] [json_publisher]: Publishing annotated image
# [INFO] [1714463960.403208861] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463960.413280270] [json_publisher]: Publishing annotated image
# [INFO] [1714463960.571530580] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463960.582274903] [json_publisher]: Publishing annotated image
# [INFO] [1714463960.787778638] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463960.798614142] [json_publisher]: Publishing annotated image
# [INFO] [1714463960.965328702] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463960.971564275] [json_publisher]: Publishing annotated image
# [INFO] [1714463961.172562198] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463961.179790774] [json_publisher]: Publishing annotated image
# [INFO] [1714463961.398600551] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463961.405384374] [json_publisher]: Publishing annotated image
# [INFO] [1714463961.562875988] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463961.571397933] [json_publisher]: Publishing annotated image
# [INFO] [1714463961.777792008] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463961.786330955] [json_publisher]: Publishing annotated image
# [INFO] [1714463961.974876718] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463961.982670202] [json_publisher]: Publishing annotated image
# [INFO] [1714463962.155932872] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463962.162120412] [json_publisher]: Publishing annotated image
# [INFO] [1714463962.363745301] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463962.369943343] [json_publisher]: Publishing annotated image
# [INFO] [1714463962.558168868] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463962.563966585] [json_publisher]: Publishing annotated image
# [INFO] [1714463962.779631833] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463962.787606262] [json_publisher]: Publishing annotated image
# [INFO] [1714463962.968850502] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [285]}}"
# [INFO] [1714463962.975686372] [json_publisher]: Publishing annotated image
# [INFO] [1714463963.190133286] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463963.196321109] [json_publisher]: Publishing annotated image
# [INFO] [1714463963.495690166] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463963.503088248] [json_publisher]: Publishing annotated image
# [INFO] [1714463963.625772792] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463963.634406809] [json_publisher]: Publishing annotated image
# [INFO] [1714463963.822440406] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463963.830483389] [json_publisher]: Publishing annotated image
# [INFO] [1714463963.979310271] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463963.987183456] [json_publisher]: Publishing annotated image
# [INFO] [1714463964.160717561] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463964.167160737] [json_publisher]: Publishing annotated image
# [INFO] [1714463964.358430522] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463964.364957215] [json_publisher]: Publishing annotated image
# [INFO] [1714463964.543973450] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463964.550226342] [json_publisher]: Publishing annotated image
# [INFO] [1714463964.747936861] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463964.754620698] [json_publisher]: Publishing annotated image
# [INFO] [1714463964.991742483] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463965.001604987] [json_publisher]: Publishing annotated image
# [INFO] [1714463965.170495324] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463965.177196527] [json_publisher]: Publishing annotated image
# [INFO] [1714463965.362264779] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463965.370005007] [json_publisher]: Publishing annotated image
# [INFO] [1714463965.556573185] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463965.562326378] [json_publisher]: Publishing annotated image
# [INFO] [1714463965.757731694] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463965.763859991] [json_publisher]: Publishing annotated image
# [INFO] [1714463965.970349075] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463965.978484838] [json_publisher]: Publishing annotated image
# [INFO] [1714463966.197646593] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463966.204390505] [json_publisher]: Publishing annotated image
# [INFO] [1714463966.392352517] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463966.416398124] [json_publisher]: Publishing annotated image
# [INFO] [1714463966.625328872] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463966.632701617] [json_publisher]: Publishing annotated image
# [INFO] [1714463966.762299574] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463966.768321647] [json_publisher]: Publishing annotated image
# [INFO] [1714463966.970116923] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463966.976340715] [json_publisher]: Publishing annotated image
# [INFO] [1714463967.176111387] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463967.185345606] [json_publisher]: Publishing annotated image
# [INFO] [1714463967.365488307] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463967.371358636] [json_publisher]: Publishing annotated image
# [INFO] [1714463967.651554138] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [285]}}"
# [INFO] [1714463967.658760786] [json_publisher]: Publishing annotated image
# [INFO] [1714463967.778870364] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463967.787340466] [json_publisher]: Publishing annotated image
# [INFO] [1714463967.975480483] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463967.982089153] [json_publisher]: Publishing annotated image
# [INFO] [1714463968.234181566] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463968.250813767] [json_publisher]: Publishing annotated image
# [INFO] [1714463968.398661622] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463968.405085026] [json_publisher]: Publishing annotated image
# [INFO] [1714463968.606543083] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463968.613560432] [json_publisher]: Publishing annotated image
# [INFO] [1714463968.778555267] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463968.784732378] [json_publisher]: Publishing annotated image
# [INFO] [1714463968.960769586] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463968.967069359] [json_publisher]: Publishing annotated image
# [INFO] [1714463969.159589240] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463969.167201881] [json_publisher]: Publishing annotated image
# [INFO] [1714463969.411523752] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463969.422122378] [json_publisher]: Publishing annotated image
# [INFO] [1714463969.571499198] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463969.579349737] [json_publisher]: Publishing annotated image
# [INFO] [1714463969.760860927] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463969.767198041] [json_publisher]: Publishing annotated image
# [INFO] [1714463969.969809926] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463969.976478109] [json_publisher]: Publishing annotated image
# [INFO] [1714463970.156419481] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463970.162432791] [json_publisher]: Publishing annotated image
# [INFO] [1714463970.422452104] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463970.435760685] [json_publisher]: Publishing annotated image
# [INFO] [1714463970.619500841] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [285]}}"
# [INFO] [1714463970.638147386] [json_publisher]: Publishing annotated image
# [INFO] [1714463970.834001467] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463970.847775024] [json_publisher]: Publishing annotated image
# [INFO] [1714463970.984849298] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463970.992851923] [json_publisher]: Publishing annotated image
# [INFO] [1714463971.165119895] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463971.172601525] [json_publisher]: Publishing annotated image
# [INFO] [1714463971.398077454] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463971.404322016] [json_publisher]: Publishing annotated image
# [INFO] [1714463971.586162412] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463971.593110604] [json_publisher]: Publishing annotated image
# [INFO] [1714463971.776309518] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463971.782670496] [json_publisher]: Publishing annotated image
# [INFO] [1714463971.984863119] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463971.992209843] [json_publisher]: Publishing annotated image
# [INFO] [1714463972.190842319] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [353], "y": [285]}}"
# [INFO] [1714463972.199340029] [json_publisher]: Publishing annotated image
# [INFO] [1714463972.387865443] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463972.393851655] [json_publisher]: Publishing annotated image
# [INFO] [1714463972.596282035] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463972.621120158] [json_publisher]: Publishing annotated image
# [INFO] [1714463972.830443094] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463972.842035135] [json_publisher]: Publishing annotated image
# [INFO] [1714463972.981023058] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463972.991313094] [json_publisher]: Publishing annotated image
# [INFO] [1714463973.166250215] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463973.173092789] [json_publisher]: Publishing annotated image
# [INFO] [1714463973.381530573] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463973.388115097] [json_publisher]: Publishing annotated image
# [INFO] [1714463973.554196615] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463973.560287430] [json_publisher]: Publishing annotated image
# [INFO] [1714463973.767131822] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463973.777420339] [json_publisher]: Publishing annotated image
# [INFO] [1714463973.976999779] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463973.986069168] [json_publisher]: Publishing annotated image
# [INFO] [1714463974.198890759] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463974.205193790] [json_publisher]: Publishing annotated image
# [INFO] [1714463974.351200406] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463974.357429474] [json_publisher]: Publishing annotated image
# [INFO] [1714463974.671540387] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463974.678040822] [json_publisher]: Publishing annotated image
# [INFO] [1714463974.811375004] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463974.820155200] [json_publisher]: Publishing annotated image
# [INFO] [1714463974.987525143] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463974.995469553] [json_publisher]: Publishing annotated image
# [INFO] [1714463975.144558241] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463975.150653238] [json_publisher]: Publishing annotated image
# [INFO] [1714463975.374228632] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463975.380307230] [json_publisher]: Publishing annotated image
# [INFO] [1714463975.595909988] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463975.602318982] [json_publisher]: Publishing annotated image
# [INFO] [1714463975.753947428] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463975.762104613] [json_publisher]: Publishing annotated image
# [INFO] [1714463975.967695671] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463975.975214632] [json_publisher]: Publishing annotated image
# [INFO] [1714463976.160446877] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463976.166605026] [json_publisher]: Publishing annotated image
# [INFO] [1714463976.356135491] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463976.363016755] [json_publisher]: Publishing annotated image
# [INFO] [1714463976.576063365] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463976.587497031] [json_publisher]: Publishing annotated image
# [INFO] [1714463976.811794656] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463976.819032107] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.008103838] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463977.014716450] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.201254233] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463977.207111828] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.367686808] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463977.374013975] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.561246091] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463977.568268045] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.773234723] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [350], "y": [286]}}"
# [INFO] [1714463977.779621900] [json_publisher]: Publishing annotated image
# [INFO] [1714463977.957477230] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463977.963834952] [json_publisher]: Publishing annotated image
# [INFO] [1714463978.167361699] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463978.176873659] [json_publisher]: Publishing annotated image
# [INFO] [1714463978.369182340] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463978.375969036] [json_publisher]: Publishing annotated image
# [INFO] [1714463978.555960843] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463978.562675885] [json_publisher]: Publishing annotated image
# [INFO] [1714463978.817277321] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463978.827799190] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.005025346] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463979.011275521] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.355986118] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463979.374659567] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.530052758] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463979.537584693] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.655007804] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463979.661769175] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.761719526] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463979.767810932] [json_publisher]: Publishing annotated image
# [INFO] [1714463979.985714349] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463979.993879562] [json_publisher]: Publishing annotated image
# [INFO] [1714463980.267034112] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463980.275058530] [json_publisher]: Publishing annotated image
# [INFO] [1714463980.408120818] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463980.419176494] [json_publisher]: Publishing annotated image
# [INFO] [1714463980.604706923] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463980.614869789] [json_publisher]: Publishing annotated image
# [INFO] [1714463980.783195527] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463980.789540879] [json_publisher]: Publishing annotated image
# [INFO] [1714463980.951045097] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463980.957742986] [json_publisher]: Publishing annotated image
# [INFO] [1714463981.177100075] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463981.186686435] [json_publisher]: Publishing annotated image
# [INFO] [1714463981.411477135] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463981.417943315] [json_publisher]: Publishing annotated image
# [INFO] [1714463981.553528965] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463981.559674430] [json_publisher]: Publishing annotated image
# [INFO] [1714463981.763053331] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463981.769344207] [json_publisher]: Publishing annotated image
# [INFO] [1714463981.959356664] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463981.965931839] [json_publisher]: Publishing annotated image
# [INFO] [1714463982.179110314] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463982.186033400] [json_publisher]: Publishing annotated image
# [INFO] [1714463982.380093054] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463982.387322630] [json_publisher]: Publishing annotated image
# [INFO] [1714463982.553050500] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463982.560685227] [json_publisher]: Publishing annotated image
# [INFO] [1714463982.812869672] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463982.825420372] [json_publisher]: Publishing annotated image
# [INFO] [1714463982.967646181] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463982.974328931] [json_publisher]: Publishing annotated image
# [INFO] [1714463983.201495493] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463983.207663125] [json_publisher]: Publishing annotated image
# [INFO] [1714463983.382410648] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463983.388459964] [json_publisher]: Publishing annotated image
# [INFO] [1714463983.560616897] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463983.567405137] [json_publisher]: Publishing annotated image
# [INFO] [1714463983.757761855] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463983.763607351] [json_publisher]: Publishing annotated image
# [INFO] [1714463983.978066619] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463983.995016744] [json_publisher]: Publishing annotated image
# [INFO] [1714463984.219214440] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463984.229238881] [json_publisher]: Publishing annotated image
# [INFO] [1714463984.394871502] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463984.402135950] [json_publisher]: Publishing annotated image
# [INFO] [1714463984.567745658] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463984.573917516] [json_publisher]: Publishing annotated image
# [INFO] [1714463984.787389323] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463984.794009810] [json_publisher]: Publishing annotated image
# [INFO] [1714463984.963259620] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463984.969190360] [json_publisher]: Publishing annotated image
# [INFO] [1714463985.315625843] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463985.324903904] [json_publisher]: Publishing annotated image
# [INFO] [1714463985.447997926] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463985.457514628] [json_publisher]: Publishing annotated image
# [INFO] [1714463985.597226789] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463985.605735465] [json_publisher]: Publishing annotated image
# [INFO] [1714463985.755675696] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463985.762027906] [json_publisher]: Publishing annotated image
# [INFO] [1714463985.973448384] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463985.985327168] [json_publisher]: Publishing annotated image
# [INFO] [1714463986.198400673] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463986.208427697] [json_publisher]: Publishing annotated image
# [INFO] [1714463986.375697718] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463986.382611790] [json_publisher]: Publishing annotated image
# [INFO] [1714463986.573720666] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463986.586893606] [json_publisher]: Publishing annotated image
# [INFO] [1714463986.808605803] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463986.815517029] [json_publisher]: Publishing annotated image
# [INFO] [1714463986.997550614] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463987.004258175] [json_publisher]: Publishing annotated image
# [INFO] [1714463987.202200872] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463987.211593645] [json_publisher]: Publishing annotated image
# [INFO] [1714463987.382357289] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463987.389822256] [json_publisher]: Publishing annotated image
# [INFO] [1714463987.575339421] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463987.581822637] [json_publisher]: Publishing annotated image
# [INFO] [1714463987.774320630] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463987.783323272] [json_publisher]: Publishing annotated image
# [INFO] [1714463987.996861615] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463988.004898327] [json_publisher]: Publishing annotated image
# [INFO] [1714463988.189230367] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [285]}}"
# [INFO] [1714463988.197046453] [json_publisher]: Publishing annotated image
# [INFO] [1714463988.384674523] [json_publisher]: Publishing JSON data: "{"yaw": [8], "point_A": {"x": [325], "y": [108]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463988.391221241] [json_publisher]: Publishing annotated image
# [INFO] [1714463988.562900217] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463988.569027393] [json_publisher]: Publishing annotated image
# [INFO] [1714463988.760735673] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463988.768070432] [json_publisher]: Publishing annotated image
# [INFO] [1714463988.957661720] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463988.963971868] [json_publisher]: Publishing annotated image
# [INFO] [1714463989.160997937] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463989.167278389] [json_publisher]: Publishing annotated image
# [INFO] [1714463989.364568318] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463989.372219859] [json_publisher]: Publishing annotated image
# [INFO] [1714463989.600707236] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714463989.607655472] [json_publisher]: Publishing annotated image
# [INFO] [1714463989.756565165] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463989.765719901] [json_publisher]: Publishing annotated image
# [INFO] [1714463989.945645050] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463989.951782021] [json_publisher]: Publishing annotated image
# [INFO] [1714463990.146166337] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463990.153532417] [json_publisher]: Publishing annotated image
# [INFO] [1714463990.370309936] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463990.379173582] [json_publisher]: Publishing annotated image
# [INFO] [1714463990.557256089] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463990.563493188] [json_publisher]: Publishing annotated image
# [INFO] [1714463990.758064406] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [108]}, "point_B": {"x": [351], "y": [286]}}"
# [INFO] [1714463990.767096860] [json_publisher]: Publishing annotated image
# [INFO] [1714463990.990922536] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463991.006506525] [json_publisher]: Publishing annotated image
# [INFO] [1714463991.234749132] [json_publisher]: Publishing JSON data: "{"yaw": [10], "point_A": {"x": [323], "y": [107]}, "point_B": {"x": [353], "y": [286]}}"
# [INFO] [1714463991.241802704] [json_publisher]: Publishing annotated image
# [INFO] [1714463991.369491815] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [323], "y": [108]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463991.375573797] [json_publisher]: Publishing annotated image
# [INFO] [1714463991.566934761] [json_publisher]: Publishing JSON data: "{"yaw": [9], "point_A": {"x": [324], "y": [107]}, "point_B": {"x": [352], "y": [286]}}"
# [INFO] [1714463991.573236586] [json_publisher]: Publishing annotated image
# ...
# [INFO] [1714464711.461018866] [json_publisher]: Publishing annotated image
# [INFO] [1714464711.615887073] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [148]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464711.624383841] [json_publisher]: Publishing annotated image
# [INFO] [1714464711.862913050] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464711.884564354] [json_publisher]: Publishing annotated image
# [INFO] [1714464712.087451860] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [344]}}"
# [INFO] [1714464712.095341041] [json_publisher]: Publishing annotated image
# [INFO] [1714464712.314281350] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464712.333240693] [json_publisher]: Publishing annotated image
# [INFO] [1714464712.522731561] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464712.529516574] [json_publisher]: Publishing annotated image
# [INFO] [1714464712.683025926] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464712.689049890] [json_publisher]: Publishing annotated image
# [INFO] [1714464712.907744380] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464712.914840150] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.064367834] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464713.071328568] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.226294505] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464713.234629311] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.426093720] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714464713.434997816] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.619037786] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464713.625225904] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.800353814] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714464713.807231195] [json_publisher]: Publishing annotated image
# [INFO] [1714464713.964619354] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [351], "y": [149]}, "point_B": {"x": [370], "y": [344]}}"
# [INFO] [1714464713.972435742] [json_publisher]: Publishing annotated image
# [INFO] [1714464714.161112914] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714464714.167623923] [json_publisher]: Publishing annotated image
# [INFO] [1714464714.450811382] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464714.457290528] [json_publisher]: Publishing annotated image
# [INFO] [1714464714.619476823] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464714.627039278] [json_publisher]: Publishing annotated image
# [INFO] [1714464714.795999826] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464714.802614530] [json_publisher]: Publishing annotated image
# [INFO] [1714464714.962511242] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464714.969664317] [json_publisher]: Publishing annotated image
# [INFO] [1714464715.160386287] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714464715.167068226] [json_publisher]: Publishing annotated image
# [INFO] [1714464715.370755365] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464715.378030119] [json_publisher]: Publishing annotated image
# [INFO] [1714464715.590513949] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464715.598979108] [json_publisher]: Publishing annotated image
# [INFO] [1714464715.805184299] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464715.814286516] [json_publisher]: Publishing annotated image
# [INFO] [1714464715.992781449] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464715.998986800] [json_publisher]: Publishing annotated image
# [INFO] [1714464716.172371947] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464716.180008491] [json_publisher]: Publishing annotated image
# [INFO] [1714464716.398027543] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464716.404326840] [json_publisher]: Publishing annotated image
# [INFO] [1714464716.599272742] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464716.607546882] [json_publisher]: Publishing annotated image
# [INFO] [1714464716.817645354] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464716.824700239] [json_publisher]: Publishing annotated image
# [INFO] [1714464717.009664624] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464717.016366736] [json_publisher]: Publishing annotated image
# [INFO] [1714464717.245037512] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [148]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464717.252555652] [json_publisher]: Publishing annotated image
# [INFO] [1714464717.451344560] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [344]}}"
# [INFO] [1714464717.459730735] [json_publisher]: Publishing annotated image
# [INFO] [1714464717.671094458] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464717.677514860] [json_publisher]: Publishing annotated image
# [INFO] [1714464717.879560158] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464717.890810510] [json_publisher]: Publishing annotated image
# [INFO] [1714464718.155593526] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [148]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464718.162029634] [json_publisher]: Publishing annotated image
# [INFO] [1714464718.340247181] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [148]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464718.351447668] [json_publisher]: Publishing annotated image
# [INFO] [1714464718.488691137] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [370], "y": [345]}}"
# [INFO] [1714464718.495432984] [json_publisher]: Publishing annotated image
# [INFO] [1714464718.731547193] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464718.738802467] [json_publisher]: Publishing annotated image
# [INFO] [1714464718.871280941] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464718.880357163] [json_publisher]: Publishing annotated image
# [INFO] [1714464719.084444237] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464719.093041678] [json_publisher]: Publishing annotated image
# [INFO] [1714464719.328517686] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [344]}}"
# [INFO] [1714464719.335756739] [json_publisher]: Publishing annotated image
# [INFO] [1714464719.489183325] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464719.497109375] [json_publisher]: Publishing annotated image
# [INFO] [1714464719.667384641] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464719.677906985] [json_publisher]: Publishing annotated image
# [INFO] [1714464719.896457619] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464719.910504748] [json_publisher]: Publishing annotated image
# [INFO] [1714464720.072786628] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464720.084374063] [json_publisher]: Publishing annotated image
# [INFO] [1714464720.263349691] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [148]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464720.272412000] [json_publisher]: Publishing annotated image
# [INFO] [1714464720.445964762] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464720.455121310] [json_publisher]: Publishing annotated image
# [INFO] [1714464720.596373604] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464720.605663115] [json_publisher]: Publishing annotated image
# [INFO] [1714464720.836230611] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464720.855921444] [json_publisher]: Publishing annotated image
# [INFO] [1714464721.017491668] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464721.027076354] [json_publisher]: Publishing annotated image
# [INFO] [1714464721.247008066] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464721.256801123] [json_publisher]: Publishing annotated image
# [INFO] [1714464721.498697777] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464721.506437816] [json_publisher]: Publishing annotated image
# [INFO] [1714464721.618015340] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464721.627254506] [json_publisher]: Publishing annotated image
# [INFO] [1714464721.813076656] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464721.820078259] [json_publisher]: Publishing annotated image
# [INFO] [1714464722.006819270] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464722.014335960] [json_publisher]: Publishing annotated image
# [INFO] [1714464722.200817660] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464722.211231904] [json_publisher]: Publishing annotated image
# [INFO] [1714464722.370434668] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464722.376886527] [json_publisher]: Publishing annotated image
# [INFO] [1714464722.643704679] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [370], "y": [345]}}"
# [INFO] [1714464722.651200057] [json_publisher]: Publishing annotated image
# [INFO] [1714464722.813375148] [json_publisher]: Publishing JSON data: "{"yaw": [4], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464722.822818649] [json_publisher]: Publishing annotated image
# [INFO] [1714464723.001221162] [json_publisher]: Skipping JSON data publishing due to missing or empty parameters
# [INFO] [1714464723.009808091] [json_publisher]: Publishing annotated image
# [INFO] [1714464723.202083604] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464723.208764914] [json_publisher]: Publishing annotated image
# [INFO] [1714464723.435336732] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464723.448040806] [json_publisher]: Publishing annotated image
# [INFO] [1714464723.572029253] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464723.578236303] [json_publisher]: Publishing annotated image
# [INFO] [1714464723.779108630] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464723.787615174] [json_publisher]: Publishing annotated image
# [INFO] [1714464724.024650726] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464724.043804200] [json_publisher]: Publishing annotated image
# [INFO] [1714464724.222206224] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464724.230815442] [json_publisher]: Publishing annotated image
# [INFO] [1714464724.512108808] [json_publisher]: Publishing JSON data: "{"yaw": [6], "point_A": {"x": [351], "y": [149]}, "point_B": {"x": [371], "y": [345]}}"
# [INFO] [1714464724.519799274] [json_publisher]: Publishing annotated image
# [INFO] [1714464724.744602840] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464724.752548090] [json_publisher]: Publishing annotated image
# [INFO] [1714464724.972245195] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [352], "y": [149]}, "point_B": {"x": [369], "y": [345]}}"
# [INFO] [1714464725.008189592] [json_publisher]: Publishing annotated image
# [INFO] [1714464725.228851611] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [369], "y": [344]}}"
# [INFO] [1714464725.235889350] [json_publisher]: Publishing annotated image
# [INFO] [1714464725.485689569] [json_publisher]: Publishing JSON data: "{"yaw": [5], "point_A": {"x": [353], "y": [149]}, "point_B": {"x": [368], "y": [345]}}"
# [INFO] [1714464725.492490212] [json_publisher]: Publishing annotated image

# %% [markdown]
# node list and topic list should be like below
#
#     ros2 node list
#
# dualsystem@dualsystem-Desktop:~/dev_ws$ ros2 node list
# /json_publisher
#
#     ros2 topic list
#
# dualsystem@dualsystem-Desktop:~/dev_ws$ ros2 topic list
# /annotated_image
# /json_data

# %% [markdown]
# video streem can be see frome this(in another terminal)
#
#     ros2 run image_view image_view --ros-args -r image:=/annotated_image

# %% [markdown]
# data stream can be see from
#
#     ros2 topic echo /json_data
